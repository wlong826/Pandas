# %% [markdown]
# # Pandas数据处理120题知识点总结
# ## 第七章 数据的读取与保存

# %% [markdown]
# ---
#
# 　ID：wlong
# 　数据分析爱好者、目前小白一枚
# 　邮箱：wlong826@163.com
# 　CSDN：**[【数分小白龙】](https://blog.csdn.net/qq_38230663)**
# 　如果有不完善的地方，欢迎小伙伴评论区留言！
# 　最近博客、和鲸每周都会有所更新，欢迎**大家关注点赞分享**哦！
#
# ---
#
# 　本文的CSDN链接：[【七、数据的读取与保存】](https://blog.csdn.net/qq_38230663/article/details/116401415?spm=1001.2014.3001.5501)
#
# 　如果有想学习爬虫的小伙伴，可以看这里：[【零基础入门Python爬虫--豆瓣、58同城、安居客等】](https://www.heywhale.com/mw/project/60be1fa8acdcb3001707b133)
#
# 　关于总结更详细的配套习题案例，看这👉：[【和鲸训练营第一期——Pandas基础】](https://www.heywhale.com/home/competition/60c086d8565cca001731537f)

# %% [markdown]
# * 注：从第四章开始，就不在放数据了，重点以知识点总结为主，关于总结的配套习题，可以看这里哦！[【和鲸训练营第一期——Pandas基础】](https://www.heywhale.com/home/competition/60c086d8565cca001731537f)

# %% [markdown]
# ## 1. 读取excel文件

# %%
pd.read_excel('./data/xxx.xlsx')

# %% [markdown]
# ## 2. 读取csv文件：pd.read_csv()

# %% [markdown]
# ### (1) 读取前10行某两列数据

# %%
pd.read_csv('data1.csv', encoding='gbk', usecols=['positionName', 'salary'], nrows=10)

# %% [markdown]
# ### (2) 读取数据并在读取数据时将'xxx'列大于10000的为改为高

# %%
pd.read_csv('data2.csv', converters={'薪资水平':lambda x : '高' if float(x) > 10000 else '低'})

# %% [markdown]
# ### (3) 读取数据，并把第一列作为索引

# %%
pd.read_csv('xxx.csv', index_col = 0)

# %% [markdown]
# ### (4) 读取数据，并设置前三列为合适的索引

# %%
pd.read_csv(filepath6, sep='\s+', parse_dates=[[0,1,2]])

# %% [markdown]
# ![image.png](https://img-blog.csdnimg.cn/20210504154606925.png?x-oss-process=image/watermark,type_ZmFuZ3poZW5naGVpdGk,shadow_10,text_aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L3FxXzM4MjMwNjYz,size_16,color_FFFFFF,t_70)

# %% [markdown]
# ## 3. 读取tsv文件：pd.read_csv()

# %%
pd.read_csv('xxx.tsv', sep = '\t')

# %% [markdown]
# ## 4. dataframe保存为csv文件

# %%
df.to_csv('xxx.csv')

# %% [markdown]
# ## 5. 读取时显示所有的行列：pd.set_option()

# %% [markdown]
# ### (1) 显示所有列

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_columns', 5) #最多显示5列

# %% [markdown]
# ### (2) 显示所有行

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_rows', 10)#最多显示10行

# %% [markdown]
# ### (3) 显示小数位数

# %%
pd.set_option('display.float_format',lambda x: '%.2f'%x) #两位

# %% [markdown]
# ### (4) 显示宽度

# %%
pd.set_option('display.width', 100)

# %% [markdown]
# ### (5) 设置小数点后的位数

# %%
pd.set_option('precision', 1)

# %% [markdown]
# ### (6) 是否换行显示

# %%
pd.set_option('expand_frame_repr', False)
# True就是可以换行显示。设置成False的时候不允许换行

# %% [markdown]
# ----

# %% [markdown]
# # 最后附上思维导图：
#
# ![Image Name](https://cdn.kesci.com/upload/image/qus7ati6nj.png)
